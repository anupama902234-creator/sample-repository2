# %%
print("hello world")
# Out:
# hello world

# %%
name="rahul"
print(name)
# Out:
# rahul

# %%
age=20
print(age)
# Out:
# 20

# %%
sport="cricket"
print(sport)
# Out:
# cricket

# %%
company="havels"
print(company)
# Out:
# havels

# %%
mathsmarks=70
print(mathsmarks)
# Out:
# 70

# %%
print("rahul"+"sharma")
# Out:
# rahulsharma

# %%
str="rama"
print(str.upper())
print(str.capitalize())
# Out:
# RAMA
# Rama

# %%
str="RAMA"
print(str.lower())
# Out:
# rama

# %%
strvr="hello world ram"
print(strvr.upper())
print(strvr.lower())
print(strvr.capitalize())
print(strvr.title())
# Out:
# HELLO WORLD RAM
# hello world ram
# Hello world ram
# Hello World Ram

# %%
print("problem_no"+" "+":1")
# Out:
# problem_no :1

# %%
stat="my name is dhruv"
i=0
while i<len(stat):
    print(stat[i], end =" ")
    i+=1
# Out:
# m y   n a m e   i s   d h r u v

# %%
name=
print(bool(name))
# Out:
# True

# %%
list=[]
print(bool(list))
# Out:
# False

# %%
a=5
b=6
print(bool(a>b))
# Out:
# False

# %%
a=eval(input("enter yiur vakue"))
print(type(a))
# Out:
# enter yiur vakue 66
# <class 'int'>

# %%
age=22
if age>=18:
    print("u can vote")
else: 
    print("you cannot vote")
# Out:
# u can vote

# %%
num=8
if num%2==0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
num=5
if num%2!=0:
    print("odd")
else:
    print("even")
# Out:
# odd

# %%
for i in range(0,5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
marks=int(input("enter the marks: "))
if marks>=90:
    print("Grade A")
elif marks>=80:
    print("grade b")
elif marks>=70:
    print("grade C")
elif marks>=60:
    print("grade d")
else:
    print("failed")
# Out:
# enter the marks:  66
# grade d

# %%
n=5
for i in range(1,n+1):
    for j in range(i):
        print("*",end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n=5
for i in range(n,0,-1):
    for j in range(i):
        print("*",end=" ")
    print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
name="dhruv"
print(name)
# Out:
# dhruv

# %%
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
a=[1,2,3,4]
print(type(a))
# Out:
# <class 'list'>

# %%
a=2
b=3
sum=a+b
print(sum)
# Out:
# 5
