# %%
a=2
b=3
if a==b:
    print("equal")
else:
    print("not")
# Out:
# not

# %%
for i in range(1,5):
    for j in range(i):
        print("*",end="")
        j+=1
        
    print()
# Out:
# *
# **
# ***
# ****

# %%
n=5
for i in range(1,n+1):
    for j in range(i):
        print("*",end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n=5
for i in range(n,0,-1):
    for j in range(i):
        print("*",end=" ")
    print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
def sum(a,b):
    return a+b
    

#sum
c=sum(974,978)
print(c)
# Out:
# 1952

# %%
lst=[2, 5, 7, 'ram']
lst.remove("ram")
print(lst)
# Out:
# [2, 5, 7]

# %%
lst=[2, 5, 7, 'ram']
lst.remove("ram")
print(lst)
# Out:
# [2, 5, 7]

# %%
lst=['shyam', 5, 7, 'ram']
for i in range(len(lst)):
    print(lst[i])
# Out:
# shyam
# 5
# 7
# ram

# %%
lst=["aam","apple","orange","banana"]
print(lst[0],lst[3],sep="\n")
lst.append("ram")
print(lst)
lst.remove("orange")
print(lst)
for i in lst:
    print(i)
# Out:
# aam
# banana
# ['aam', 'apple', 'orange', 'banana', 'ram']
# ['aam', 'apple', 'banana', 'ram']
# aam
# apple
# banana
# ram

# %%
lst=[1,4,4,3,673,3]
lst.sort()
print(lst)
# Out:
# [1, 3, 3, 4, 4, 673]

# %%
set={1,2,3}
print(set)
# Out:
# {1, 2, 3}
