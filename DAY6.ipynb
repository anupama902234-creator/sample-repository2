# %%
import matplotlib.pyplot as plt
employes=["Raja","riya","Rishi","Priya","suraj","parus"]
age=[22,20,30,40,50,60]
salary=[10000,23000,21000,20200,22000,31000]

plt.pie(salary, labels=employes)
plt.title("Employ salary Distrubution")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data=np.array([
    [90,80,88],
    [70,77,65],
    [80,90,87],
])
plt.imshow(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data=np.array([
    [20,80,88],
    [70,77,15],
    [0.9,90,87],
])
plt.imshow(data)
plt.show()

# %%
import matplotlib.pyplot as plt
age=[22,20,30,40,50,60]
salary=[10000,23000,21000,20200,22000,31000]

plt.plot(salary,age) import matplotlib.pyplot as plt
age=[22,20,30,40,50,60]
salary=[10000,23000,21000,20200,22000,31000]

plt.plot(salary,age) 
plt.show()

# %%
import matplotlib.pyplot as plt
age=[22,20,30,40,50,60]
salary=[10000,23000,21000,20200,22000,31000]
plt.barh(age,salary)
# Out:
# <BarContainer object of 6 artists>
