# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
students=["amit","rahul","priya","neha"]
marks=[80,90,50,60]
plt.pie(marks,labels=students)
#plt.barh(students,marks,color="orange")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data=np.array([
    [90,80,70],
    [60,70,80],
    [20,30,40],
    [40,50,60]
])
plt.imshow(data)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
students=["amit","rahul","priya","neha"]
marks=[80,90,50,60]
plt.plot(students,marks,color="purple")

# %%
import matplotlib.pyplot as plt
students=["amit","rahul","priya","neha"]
marks=[80,90,50,60]
plt.barh(students,marks,color="orange")
plt.show()

# %%
import matplotlib.pyplot as plt
students=["amit","rahul","priya","neha"]
marks=[80,90,50,60]
plt.bar(students,marks,color="orange")
plt.show()
