# %%
from sklearn.linear_model import LinearRegression
X=[[1000],[1200],[1500],[1800]]
Y=[40,50,5,80]
model=LinearRegression()
model.fit(X,Y)
prediction=model.predict([[1600]])
print("Predicted Price:",prediction[0],"Lakh")
# Out:
# Predicted Price: 50.40816326530612 Lakh
